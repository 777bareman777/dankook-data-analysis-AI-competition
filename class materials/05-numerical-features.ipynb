# %% [markdown]
# # 수치형변수 가공 데모

# %% [markdown]
# ## 라이브러리 import 및 설정

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import rcParams, pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from warnings import simplefilter

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
simplefilter('ignore')

# %% [markdown]
# ## 학습데이터 로드

# %% [markdown]
# 학습데이터는 데이콘 [영화 관객수 예측 모델 개발](https://dacon.io/competitions/open/235536/data/) 페이지에서 다운로드하여 `../data/movies/` 폴더에 저장해 둔다.

# %% [markdown]
# 이 데이터는 영화의 장르, 개봉일, 상영시간 등과 같은 데이터로 영화 총 관객수 (`box_off_num`)를 예측하는 데이터이다.

# %%
data_dir = Path('../input/movies/')
trn_file = data_dir / 'movies_train.csv'
seed = 42

# %%
df = pd.read_csv(trn_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (600, 11)
#             distributor genre release_time  time screening_rat director  \
# title
# 개들의 전쟁         롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 내부자들             (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 나는 공무원이다         (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 불량남녀       쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#            dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# title
# 개들의 전쟁                NaN             0         91          2        23398
# 내부자들           1161602.50             2        387          3      7072501
# 은밀하게 위대하게       220775.25             4        343          4      6959083
# 나는 공무원이다         23894.00             2         20          6       217866
# 불량남녀                 1.00             1        251          2       483387

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 개들의 전쟁 to 베를린
# Data columns (total 11 columns):
# distributor       600 non-null object
# genre             600 non-null object
# release_time      600 non-null object
# time              600 non-null int64
# screening_rat     600 non-null object
# director          600 non-null object
# dir_prev_bfnum    270 non-null float64
# dir_prev_num      600 non-null int64
# num_staff         600 non-null int64
# num_actor         600 non-null int64
# box_off_num       600 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 56.2+ KB

# %% [markdown]
# 독립변수를 포함 총 6개의 수치형변수가 있다. 그 중 `dir_prev_bfnum`은 결측값이 많음을 확인할 수 있다.

# %%
df.fillna(0, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 개들의 전쟁 to 베를린
# Data columns (total 11 columns):
# distributor       600 non-null object
# genre             600 non-null object
# release_time      600 non-null object
# time              600 non-null int64
# screening_rat     600 non-null object
# director          600 non-null object
# dir_prev_bfnum    600 non-null float64
# dir_prev_num      600 non-null int64
# num_staff         600 non-null int64
# num_actor         600 non-null int64
# box_off_num       600 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 56.2+ KB

# %% [markdown]
# 결측값을 0으로 대체하였다.

# %%
df.describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor  \
# count  600.000000    6.000000e+02    600.000000  600.000000  600.000000
# mean   100.863333    4.726993e+05      0.876667  151.118333    3.706667
# std     18.097528    1.309474e+06      1.183409  165.654671    2.446889
# min     45.000000    0.000000e+00      0.000000    0.000000    0.000000
# 25%     89.000000    0.000000e+00      0.000000   17.000000    2.000000
# 50%    100.000000    0.000000e+00      0.000000   82.500000    3.000000
# 75%    114.000000    3.761416e+05      2.000000  264.000000    4.000000
# max    180.000000    1.761531e+07      5.000000  869.000000   25.000000
#
#         box_off_num
# count  6.000000e+02
# mean   7.081818e+05
# std    1.828006e+06
# min    1.000000e+00
# 25%    1.297250e+03
# 50%    1.259100e+04
# 75%    4.798868e+05
# max    1.426277e+07

# %% [markdown]
# 수치형변수의 분포로부터 모든 수치형변수가 0이나 양수의 값을 가짐을 알 수 있다.

# %%
target_col = 'box_off_num'
pred_col = 'pred'
num_cols = [x for x in df.columns if df[x].dtype in [np.int64, np.float64] and x != target_col]
print(num_cols)
# Out:
# ['time', 'dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor']

# %%
df.box_off_num.hist(bins=50)

# %%
sns.pairplot(data=df, vars=num_cols + [target_col], size=5)

# %% [markdown]
# 수치형변수 중 `time`은 정규분포에 가깝고 나머지는 멱함수 (power-law)분포에 가깝다.

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_5d3302b4_f734_11ea_a712_acde48001122row0_col0 {
#             background-color:  #023858;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row0_col1 {
#             background-color:  #d4d4e8;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row0_col2 {
#             background-color:  #c0c9e2;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row0_col3 {
#             background-color:  #4697c4;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row0_col4 {
#             background-color:  #f0eaf4;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row0_col5 {
#             background-color:  #a7bddb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col0 {
#             background-color:  #e2dfee;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col1 {
#             background-color:  #023858;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col2 {
#             background-color:  #a1bbda;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col3 {
#             background-color:  #b9c6e0;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col4 {
#             background-color:  #fbf3f9;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row1_col5 {
#             background-color:  #dad9ea;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col0 {
#             background-color:  #d8d7e9;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col1 {
#             background-color:  #a8bedc;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col2 {
#             background-color:  #023858;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col3 {
#             background-color:  #9ab8d8;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row2_col5 {
#             background-color:  #e3e0ee;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col0 {
#             background-color:  #4e9ac6;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col1 {
#             background-color:  #b1c2de;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col2 {
#             background-color:  #8bb2d4;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col3 {
#             background-color:  #023858;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col4 {
#             background-color:  #f5eff6;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row3_col5 {
#             background-color:  #79abd0;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col3 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col4 {
#             background-color:  #023858;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col0 {
#             background-color:  #a8bedc;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col1 {
#             background-color:  #cccfe5;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col2 {
#             background-color:  #d1d2e6;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col3 {
#             background-color:  #71a8ce;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col4 {
#             background-color:  #f0eaf4;
#         }    #T_5d3302b4_f734_11ea_a712_acde48001122row5_col5 {
#             background-color:  #023858;
#         }</style>
# <table id="T_5d3302b4_f734_11ea_a712_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >time</th>
#         <th class="col_heading level0 col1" >dir_prev_bfnum</th>
#         <th class="col_heading level0 col2" >dir_prev_num</th>
#         <th class="col_heading level0 col3" >num_staff</th>
#         <th class="col_heading level0 col4" >num_actor</th>
#         <th class="col_heading level0 col5" >box_off_num</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5d3302b4_f734_11ea_a712_acde48001122level0_row0" class="row_heading level0 row0" >time</th>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col0" class="data row0 col0" >1</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col1" class="data row0 col1" >0.266065</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col2" class="data row0 col2" >0.306727</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col3" class="data row0 col3" >0.623205</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col4" class="data row0 col4" >0.114153</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row0_col5" class="data row0 col5" >0.441452</td>
#     </tr>    <tr>
#         <th id="T_5d3302b4_f734_11ea_a712_acde48001122level0_row1" class="row_heading level0 row1" >dir_prev_bfnum</th>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col0" class="data row1 col0" >0.266065</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col1" class="data row1 col1" >1</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col2" class="data row1 col2" >0.396616</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col3" class="data row1 col3" >0.369657</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col4" class="data row1 col4" >0.042491</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row1_col5" class="data row1 col5" >0.293791</td>
#     </tr>    <tr>
#         <th id="T_5d3302b4_f734_11ea_a712_acde48001122level0_row2" class="row_heading level0 row2" >dir_prev_num</th>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col0" class="data row2 col0" >0.306727</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col1" class="data row2 col1" >0.396616</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col2" class="data row2 col2" >1</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col3" class="data row2 col3" >0.450706</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col4" class="data row2 col4" >0.0140059</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row2_col5" class="data row2 col5" >0.259674</td>
#     </tr>    <tr>
#         <th id="T_5d3302b4_f734_11ea_a712_acde48001122level0_row3" class="row_heading level0 row3" >num_staff</th>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col0" class="data row3 col0" >0.623205</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col1" class="data row3 col1" >0.369657</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col2" class="data row3 col2" >0.450706</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col3" class="data row3 col3" >1</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col4" class="data row3 col4" >0.0778706</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row3_col5" class="data row3 col5" >0.544265</td>
#     </tr>    <tr>
#         <th id="T_5d3302b4_f734_11ea_a712_acde48001122level0_row4" class="row_heading level0 row4" >num_actor</th>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row4_col0" class="data row4 col0" >0.114153</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row4_col1" class="data row4 col1" >0.042491</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row4_col2" class="data row4 col2" >0.0140059</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row4_col3" class="data row4 col3" >0.0778706</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122row4_col4" class="data row4 col4" >1</td>
#         <td id="T_5d3302b4_f734_11ea_a712_acde48001122ro

# %% [markdown]
# ## 선형회귀 모델 학습

# %% [markdown]
# ### RMSE/RMSLE 손실함수 정의

# %%
rmse = lambda y, p: np.sqrt(mean_squared_error(y, p))
rmsle = lambda y, p: np.sqrt(mean_squared_error(np.log1p(y), np.log1p(p)))

# %% [markdown]
# ### 변수 가공없이 선형회귀 모델 학습

# %%
lr = LinearRegression()
lr.fit(df[num_cols], df[target_col])
df[pred_col] = lr.predict(df[num_cols])

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	  1500066.43

# %%
sns.pairplot(data=df, vars=[pred_col, target_col], size=4, plot_kws={'alpha': .5})

# %% [markdown]
# 예측값 중 음수가 존재하고 큰 값의 예측은 비교적 정확한 반면 적은 값의 예측은 오차가 많이 발생하였다.

# %% [markdown]
# ### 멱함수 분포 변수 `log1p` 변환

# %%
df.box_off_num.apply(np.log1p).hist(bins=50)

# %% [markdown]
# 멱함수 분포의 수치형 변수는 `np.log1p()` 함수로 정규분포에 가깝게 변환할 수 있다. 역변환은 `np.expm1()` 함수를 이용하면 된다.

# %%
lr = LinearRegression()
lr.fit(df[num_cols], np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(df[num_cols]))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{rmsle(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	 17129211.69
# RMSLE:	        2.12

# %%
sns.pairplot(data=df, vars=[pred_col, target_col], size=4, plot_kws={'alpha': .5})

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df[target_col], df[pred_col], alpha=.5)
plt.xlabel('box_off_num')
plt.ylabel('prediction')
plt.yscale('log')
plt.xscale('log')

# %%
df[num_cols].describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor
# count  600.000000    6.000000e+02    600.000000  600.000000  600.000000
# mean   100.863333    4.726993e+05      0.876667  151.118333    3.706667
# std     18.097528    1.309474e+06      1.183409  165.654671    2.446889
# min     45.000000    0.000000e+00      0.000000    0.000000    0.000000
# 25%     89.000000    0.000000e+00      0.000000   17.000000    2.000000
# 50%    100.000000    0.000000e+00      0.000000   82.500000    3.000000
# 75%    114.000000    3.761416e+05      2.000000  264.000000    4.000000
# max    180.000000    1.761531e+07      5.000000  869.000000   25.000000

# %%
df[['dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor']] = df[['dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor']].apply(np.log1p)
df[num_cols].describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor
# count  600.000000      600.000000    600.000000  600.000000  600.000000
# mean   100.863333        5.305796      0.462197    4.026352    1.446130
# std     18.097528        6.254561      0.555570    1.789517    0.446256
# min     45.000000        0.000000      0.000000    0.000000    0.000000
# 25%     89.000000        0.000000      0.000000    2.890372    1.098612
# 50%    100.000000        0.000000      0.000000    4.424829    1.386294
# 75%    114.000000       12.837611      1.098612    5.579730    1.609438
# max    180.000000       16.684279      1.791759    6.768493    3.258097

# %% [markdown]
# 수치형 독립변수 중 멱변환 분포를 따르는 변수에도 `np.log1p()` 변환을 적용하였다.

# %%
sns.pairplot(data=df, vars=num_cols, size=5)

# %%
lr = LinearRegression()
lr.fit(df[num_cols], np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(df[num_cols]))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{rmsle(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	  1883568.88
# RMSLE:	        2.32

# %% [markdown]
# RMSLE는 조금 나빠졌지만 RMSE는 크게 개선이 되었다.

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df[target_col], df[pred_col], alpha=.5)
plt.xlabel('box_off_num')
plt.ylabel('prediction')
plt.yscale('log')
plt.xscale('log')

# %%
df.head()

# %% [markdown]
# ### 날짜/시간 변수 처리

# %%
df['release_time'] = pd.to_datetime(df['release_time'])
df['release_time'].describe()
# Out:
# count                     600
# unique                    330
# top       2015-08-13 00:00:00
# freq                        6
# first     2010-01-02 00:00:00
# last      2015-12-31 00:00:00
# Name: release_time, dtype: object

# %%
df['year'] = df['release_time'].dt.year
df['month'] = df['release_time'].dt.month
df.head()

# %%
num_cols += ['year', 'month']
print(num_cols)
# Out:
# ['time', 'dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor', 'year', 'month']

# %%
lr = LinearRegression()
lr.fit(df[num_cols], np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(df[num_cols]))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')

# %% [markdown]
# ### 정규화/스케일링

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df[num_cols])

lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(df[num_cols])

lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-9606b77c4b28> in <module>()
#       1 scaler = MinMaxScaler()
# ----> 2 X = scaler.fit_transform(df[num_cols])
#       3
#       4 lr = LinearRegression()
#       5 lr.fit(X, np.log1p(df[target_col]))
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['year' 'month'] not in index"

# %% [markdown]
# ### Binning

# %%
df['time_bin'] = pd.qcut(df['time'], 4, labels=False)
sns.pairplot(data=df, vars=['time', 'time_bin'], size=4, plot_kws={'alpha': .5})

# %%
df['time_bin'] = pd.qcut(df['time'], 4, labels=False)
df[['time', 'time_bin']].head(10)

# %%
X = pd.concat([df[num_cols], pd.get_dummies(pd.qcut(df['time'], 4, labels=False))], axis=1)
X.shape

# %%
lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')

# %%
X = pd.concat([df[[x for x in num_cols if x != 'month']], 
               pd.get_dummies(pd.qcut(df['time'], 4, labels=False)),
               pd.get_dummies(df['month'])], axis=1)
X.shape

# %%
lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	  2925429.22
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-b605d4d1fd4a> in <module>()
#       4
#       5 print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
# ----> 6 print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')
#
# NameError: name 'RMSLE' is not defined

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df[target_col], df[pred_col], alpha=.5)
plt.xlabel('box_off_num')
plt.ylabel('prediction')
plt.yscale('log')
plt.xscale('log')

# %% [markdown]
# ### 2차 다항회귀 (Polynomial Regression)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)
X = poly.fit_transform(df[num_cols])
print(X.shape)

# %%
lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMSLE:\t{RMSLE(df[target_col], df[pred_col]):12.2f}')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df[target_col], df[pred_col], alpha=.5)
plt.xlabel('box_off_num')
plt.ylabel('prediction')
plt.yscale('log')
plt.xscale('log')
